# %% [markdown]
# # Python

# %% [markdown]
# ## 1.0 Installing Python
#
# <https://www.python.org>
#
# winget install Python.Python.3.14  -- PowerShell
#
# ----

# %% [markdown]
# ## 1.1 IDEs
#
# 1) Visual Studio Code       <https://code.visualstudio.com/download>
# Extensions :
#             Python
#             Pylance
#             Jupyter
#             ... Explore
#
# 2) Jupyter Notebook         <https://jupyter.org>
# 3) Pycharm  -- JetBrains    <https://www.jetbrains.com/pycharm/download>
# 4) Anaconda Navigator       <https://www.anaconda.com/download>
# 5) Google Colab (Online) -- Not Recommended
#
# ----

# %% [markdown]
# ## 2.0 Writing With Python

# %%
print("Hello world")

# %%
print(
    """
    This is my first App
    Welcome to python
    """
)

# %%
print("This is my first App\nWelcome to python")

# %%
print("This is my first App")
print("Welcome to python")

# %%
print("Welcome to Python", end=" - ")
print("This is my first App")

# Comment -> ( # )

# %% [markdown]
# ## 2.1 Variables / Data Types

# %%
# Variable Can Start wite Letters or _ but not with numbers

full_name = "Omar Wahby"
student_age = 22
_full_name = "Omar Wahby"
_22 = 22

## 88_boom = "Boom" # ----> not valid variable name because it starts with number

# snake format   ->  full_name   student_age
# camel format   ->  fullName   studentAge   studentFullName
# pascal format ->  FullName   StudentAge   StudentFullName

print (_22)
print (_full_name)

# %%
Message = "Data Data Data"
Sender = "Omar"
Age = 22
is_student = True
Skills_list = ["Python", "Java", "SQL"]

print(Message)
print(Sender)
print(Age)
print(is_student)
print(Skills_list)

print(Sender * 3)



print((Sender + "   ") * 3)

# %%
print(type(Message))
print(type(Sender))
print(type(Age))
print(type(is_student))
print(type(Skills_list))

# %%
age = float(Age)

print(Age)
print(type(age))

# %%
Message_1 = "22" # String
print (Message_1)

Message_2 = int (Message_1) # Convert String to Integer
print (type(Message_2))

print (Message_2 + 1)

Message_3 = "22A" # String 
print (Message_3)
# Message_4 = int (Message_3)  # ----> Error because it contains non-numeric characters

# %%
text = ""
print (text)
print (type(text))

# %%
text = bool(text)
print (text)

# %% [markdown]
# ## 2.2 math operators

# %%
num1 = 20
num2 = 6

print(num1 + num2)  # addition
print(num1 - num2)  # subtraction
print(num1 * num2)  # multiplication
print(num1 / num2)  # division   -> float
print(num1 // num2) # division   -> float   -> integrer
print(num1 % num2)  # mod   20 = 6 + 6 + 6 + 2  # remainder -> 2  , quotient -> 3
print(num1 ** 2)    # pow

# %% [markdown]
# ## 2.3 Input / Output Data

# %%
message = input("Enter your message: ")
print("Your message is : " + message) # -> (+) is used to concatenate strings -> Named ( Concatenation operator )

# %%
Message = input("Enter your message: ")
Sender = input("Enter your name: ") 
Age = int(input("Enter your age: "))
is_student = input("Are you a student? (yes/no): ") == "yes"
Skills_list = input("Enter your skills separated by commas: ").split(",")
Salery = float(input("Enter Our Expected Salery: "))

print("Message:", Message)
print("Sender:", Sender)
print("Age:", Age)
print("Is Student:", is_student)
print("Skills List:", Skills_list)
print("Salery:", Salery)

# %%
is_student = input("Are you a student? (yes/no): ").strip().lower() == "yes"
print("Is Student:", is_student)

# %%
print(f"Expected Salery is : ${Salery:.2f}")  
print(f"Expected Salery is : {Salery:.2f}")

# %%
# Find The Area of Rectangle
# length , width

length = int(input("Enter the length: "))
width = int(input("Enter the width: "))

area = length * width

print(f"The Area is {area}")

# %% [markdown]
# ## 2.4 IF Conditions

# %%
Age = 18
Age = int(input("Enter your age: "))
if Age >= 18 : 
    print("Access Granted")
    
else:
    print("Access Denied")

# %%
Age = int(input("Enter your age: "))
          
if Age >= 23 : 
    print("Graduated")
elif Age >= 18:
    print("Collage Student")
else:
    print("School Student")

# %%
# Task Calculator
# ask the user to enter 2 numbers and the operation he need and make it 
# if the user enter wrong operation print("enter valid operation")









num1 = float(input("Enter num1:"))
num2 = float(input("Enter num2:"))
operation = input("Enter operation (+ , - , / , * ):")


if operation == "+":
    print(num1 + num2)
elif operation == "-":
    print(num1 - num2)
elif operation == "/":
    print(num1 / num2)
elif operation == "*":
    print(num1 * num2)
else: 
    print(f"{operation} is not allowed, please enter a valid oepration")

# %%
num = int(input("Enter a num"))

num_type = "Even" if num % 2 == 0 else "Odd"

print("Even" if num % 2 == 0 else "Odd")
print (num_type)

# %% [markdown]
# ### Match Statement
#
#
# The match statement selects one of many code blocks to be executed

# %%
x = 2

match x:
    case 1:
        print("one")
    case 2:
        print("two")
    case 3:
        print("three")

# %%
day = 4
match day:
  case 1:
    print("Monday")
  case 2:
    print("Tuesday")
  case 3:
    print("Wednesday")
  case 4:
    print("Thursday")
  case 5:
    print("Friday")
  case 6:
    print("Saturday")
  case 7:
    print("Sunday")

# %% [markdown]
# ## 2.5 Loop Statement
#
# For  -> the cound of times

# %%
range(10) # End = 10  
print(range(10))
print(type(range(10)))

# %%
# for loop 

for i in range(10):
    print(i , end=" - ")
    
print ()

# range (start , end , step) 

for i in range(1 , 10 , 2):
    print(i , end=" - ")
    
print ()

for i in range(10 , 0 , -2):
    print(i , end=" - ")
    
print ()

# %%
for i in range (5):    # nested loop
    for j in range(5):  
        print(j)

    print(f"Circle {i} Done ")

# %%
for i in range (10):   
    for j in range(10):
        if (j < i):
           print("*", end= "") 
    print()

# %%
n = 10

for i in range(n):
    print(" " * (n - i - 1) + "*" * (2*i + 1))

for i in range(n-2, -1, -1):
    print(" " * (n - i - 1) + "*" * (2*i + 1))

# %% [markdown]
# While -> until the condition is true

# %%
# while Loop

count = 0
while count <= 10:
    print(count)
    count = count + 1

# %%
# Infinite Loop

count = 0
# while count <= 10:
#    print(count)

# %%
count = 0
while count <= 9:
    for i in range (5):
        print("Data Data Data")
    print (f"Hacker Rank {count}")
    count = count + 1

# %%
# Break || Continue
count = 0

while count <= 5:
    if count == 3: 
        print("The count = 3")
        # break
        # continue
    else :
        print(count)
    count = count + 1

# %%
# Continue
count = 0

while count < 5:
    count = count + 1
    if count == 3: 
        continue
    print (count)

# %% [markdown]
# ----
#
# ----

# %%
# Write list of something like Purchase list 

entries = []

order = ""

while order != "q":
    
    order = input("Enter your name:")
    entries.append(order)
    print(order)
    
print(entries)

# %%
entries = []

order = ""

while True :
    order = input("Enter your name:")

    if order == "q":
        break
    
    entries.append(order)
    print(order)
    
print(entries)

# %% [markdown]
# ## 2.7 Indexing and Slicing

# %% [markdown]
# Slice Operator ( : ) -> For any Sequence
#
# Syntax : sequence[start : end : step]  or sequence[start : end ]

# %%
# Indexing and Slicing

text = "Hello World"

print(text[0])
print(text[1])
print(text[-5])
print(text[1:5])
print(text[:9])
print(text[:9:2])
print(text[::-1])
print(text[0:4:2])
print(text[::2])
print(text[::3])

# %%
text = "Hello-to Python"

print(len(text))
print(text.find("e"))
print(text.rfind("e"))
print(text.count("s"))
print(text.upper())
print(text.lower())
print(text.capitalize())
print(text.title())
print(text.split("-"))
print(text.startswith("Welocme"))
print(text.endswith("Welocme"))
print(text.strip())
print(text.replace("o" , "a"))

# %% [markdown]
# ## 2.8 Built-in Data Types
#
#  ### 1)  list -> Mutable , Ordered , Allow Duplicates , Indexing , Sorting
#
#  syntax : [1,2,3,4,5]

# %%
names = ['Alaa', "Ahmed","Mohamed"]
print(names) 
print (sorted(names))
print (names.sort())
print(type(names))
print(names)

# %%
list("Omar")

# %%
dir(list)

# %%
help(list)

# %%
lst = [5, 2, 4]

# sort
lst.sort()
print(lst)  
# [2, 4, 5]

# sorted
lst = [5, 2, 4]
new_lst = sorted(lst)
print(lst)      # [5, 2, 4]
print(new_lst)  # [2, 4, 5]

# %%
names = [["Shahd", "Ahmed"], ["Mohamed", "Omar"] , 20 , True , "Omar Wahby"]
print(names)

# %%
names = [["Shahd", "Ahmed"], ["Mohamed", "Omar"] , 20 , True , "Omar Wahby"]


print(names[0])
print(names[0][1])
print(names[1])
print(len(names))
print(len(names[0]))
print(len(names[0][0]))
# print(sorted(names)) # ---> Error because the list contains different data types and it cannot be sorted

# %%
names_copy = names.copy()
print(names_copy)

# %%
list1 = ["a","b","c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)

# %%
list1 = ["a","b","c"]


# insert (index , value)
list1.insert(6,"d")
list1.insert(1,"e")
list1.insert(-1,"f")
print(list1)
print(list1.index("d"))

# %%
list1 = ["a","b","c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)

# %%
list1 = ["a","b","c"]

print (list1.index("b"))
print(list1.count("b"))  #  why 1 ?????

# %%
list1 = ["a","b","c","b","B"]

print (list1.index("b"))
print(list1.count("b")) # it's count the number of times "b" appears in the list

# %%
list1 = [1,2,3,4,5]

list1.reverse()

print(list1)
print(list1.reverse())  # why None ?????? because the reverse method does not return anything it just modifies the original list and returns None
print (reversed(list1)) # why back object because the reversed function

list2 = list(reversed(list1))
print(list2)

# %%
list1 = [1,2,3,4,5]

list1.remove(3) # Remove the first occurrence of the value 3 from the list

print(list1)

# %%
list1 = [1,2,3,4,5]

list1.remove(list1[1]) # Remove the element at index 1 which is 2

print(list1)
print(list1.remove(list1[1]))

# %%
list1 = [1,2,3,4,5]

list1.pop(2) # Remove the element at index 2

print(list1)
print (list1.pop(2))

# %%
list1 = [1,2,3,4,5]

del list1[1] # Remove the element at index 1 which is 2

print(list1)

del list1[0:3:2] 

print(list1)

# %%
list1 = [1,2,3,4,5]

list1.clear() # Remove all elements from the list

print(list1)

# %% [markdown]
# ### 2) Tuple -> Immutable , Ordered , Allow Duplicates , Indexing , No Sorting
#
# syntx : (1,2,3,4,5)
#
# <p align="center">
#   <strong style="font-size:32px;">Unchangeable</strong>
# </p>

# %%
names = ('Omar','Alaa','Baraa')

print(names)
print(type(names))

# %%
dir(tuple)

# %%
names = ('Omar','Alaa','Omar','Baraa')
names1 = ('Omar','Alaa','Baraa')

print(names + names1)
print (names[2])
print(names.count("Omar"))
print(names.index("Alaa"))
print(len(names))

del names

# %%
# Change the value of tuple

names = list(names) # Convert tuple to list
print(names)
names[0] = "Ahmed"
print(names)
names = tuple(names) # Convert list to tuple
print(names)

# %%
# Unpacking tuple

names = ("Omar","Alaa","Baraa")
a,b,c = names
print(a)
print(b)
print(c)

# %% [markdown]
# ### 3) Set -> Mutable , unordered , cannot change items but can remove and add , Duplicates Not Allowed , Not Sorted
#
# Syntax : {1,2,3,4,5}

# %%
Numbers = {1,1,1,1,1,2,2,2,3,3,4,5}
print (Numbers)

# %%
list1 = [True , False , 0 , 0 , 1 , 1 ,  2 , 1.5, 2 , "omar" , "OMAR"]

Set = set(list1)

print (Set)

# %%
dir(set)

# %%
Set.difference(Numbers)

# %%
Set.union(Numbers)

# %%
Set.add("Omar")
print(Set)

# %%
Set.update(Numbers)
print(Set)

# %%
list2 = [6,7,8]

Set.update(list2)
print(Set)

# %%
Set.remove(1.5)
print(Set)

# %%
Set.discard(2)
print(Set)

# %%
print(Set.pop()) # Remove first element 
print(Set)

# %%
Set.clear() 
print(Set)

# %%
del Set 
# print(Set) # error ----> No Set Exist

# %% [markdown]
# ### Frozenset -> make set  - Immutable ( Can't add or remove )

# %%
x = frozenset({1,2,3})
print(x)
print(type(x))
# x.clear() # error because frozenset is immutable and does not have a clear method

# %%
dir(frozenset)

# %%
help(frozenset)

# %% [markdown]
# ### 4. Dictionary -> Ordered , Mutable

# %%
Dict = {"Name":"Omar" , "Age":22 , "Skills":["Python","Java","SQL"]}
print(Dict)

# %%
print(Dict["Name"])
print(Dict["Age"])
print(Dict["Skills"])

# %%
Dict = {"Name":"Omar" , "Name":"Ahmed","Name":"Baraa","name":"Omar" , "Age":22 , "Skills":["Python","Java","SQL"]}
print(Dict) 
print(Dict["Name"])
# Keys need to be unique in a dictionary

# %%
print (len(Dict))
x = Dict.keys()
print (x)
y = Dict.values()
print (y)

z = Dict.items()
print (z)
# print(z["Name"]) # error ----> why error because z is a view object that contains tuples of key-value pairs

# %%
for key,value in z:
    print(f"Key: {key} , Value: {value}")

# %%
Dict2 = dict(zip(x, y))
print(Dict2)

# %%
x = ["a","b","c","d","f"]
y = [1,2,3]

z = zip(x,y)

print(z) # why zip object because the zip function returns a zip object which is an iterator that generates tuples of the elements from the input iterables
print(type(z))
print(list(z))
print(set(z)) # why empty because the zip object is an iterator and it can be exhausted only once
print(set(zip(x,y)))
print(dict(z))
print(dict(zip(x,y)))

# %%
x = ["a","b","c","d","f"]
y = [1,2,3]

z = zip(x,y)

print (dict(z))

# %%
x = ["a","b","c","d","f"]
y = [1,2,3]

z = zip(x,y)

for pair in z:
    print(pair)

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()

print(x) #before the change

car["color"] = "white"

print(x) #after the change

# %%
car["brand"] = "BMW"

print(car)

# %%
car.update({"engine" : "FF_65"})
print(car)

# %% [markdown]
# ### Nested Dictionary

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

print (myfamily)
print (myfamily["child1"])
print (myfamily["child1"]["name"])

# %%
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

# %%
for x, obj in myfamily.items():
  print(x)

  for y in obj:
    print(y + ':', obj[y])

# %%
help(dict)

# %% [markdown]
# ### 1)  list -> Mutable , Ordered , Allow Duplicates , Indexing , Sorting
#
# ### 2) Tuple -> Immutable , Ordered , Allow Duplicates , Indexing , No Sorting
#
# ### 3) Set -> Mutable , Unordered , cannot change items but can remove and add , Duplicates Not Allowed , Not Sorted
#
# ### 4) Dictionary -> Mutable , Ordered

# %% [markdown]
# ## 2.9  Function

# %%
def hi():
    print("Hello World")
    
hi()
hi()
hi()

# %%
def hi(name):
    print(f"Hello {name}")
    
hi("Omar")
hi("Alaa")

# %%
x = input("Enter your name: ")
hi(x)

# %%
def Sum(num1 , num2):
    return num1 + num2

print(Sum(2,3))

x = int(input("Enter num1: "))
y = int(input("Enter num2: "))
print(Sum(x,y))

# %%
def multiply(num1 , num2):
    return num1 * num2

print(multiply(2,3))

# %%
def fun1():
    for i in range(10):
        print(i)
        

fun1()

# %%
x = fun1()

# %%
print(x)

# %%
print(type(x))

# %%
def get_Salary():
    salary = float(input("Enter your salary: "))
    return salary

x = get_Salary()


print(x) 
print(type(x))

# %%
def net_salary(salary , tax):
    net = salary - tax
    return net

net = net_salary(1000, 200)
print(net)

# %%
def get_info (name , age):
    print(f"Your name is {name} and your age is {age}")
    
get_info("Omar", 22)

print(get_info("Omar", 22))

# %%
def get_info (name , age):
    print(f"Your name is {name} and your age is {age}")
    return f"Your name is {name} and your age is {age}"

get_info("Omar", 22)

print(get_info("Omar", 22))

# %%
def get_info (name = "None" , age = 0):
    return f"Your name is {name} and your age is {age}"

get_info()

get_info("Omar", 22)

# %%
## Task : Create a function that find the area of circle (r *r * ( pi = 3.14) )









def get_area_circle(r) :
    area = r * r * 3.14
    return area

# %%
def get_area_circle() :
    input_radius = int(input("Enter radius : "))
    area = input_radius * input_radius * 3.14
    area = int(area)
    return area

get_area_circle()

# %%
def get_area_circle(input_radius) :
    input_radius = int(input("Enter radius : "))
    area = input_radius * input_radius * 3.14
    area = int(area)
    return area

get_area_circle(5)
